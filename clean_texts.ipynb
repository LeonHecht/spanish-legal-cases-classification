# %%
# Función para hacer la limpieza del texto de todos los archivos.
import re
import os

def transformar_y_guardar_archivo(input_file, output_folder, output_filename):

    # Intenta abrir el archivo con encoding 'utf-8', si falla, intenta con 'latin-1'
    try:
        with open(input_file, 'r', encoding='utf-8') as file:
            contenido_transformado = file.read()
    except UnicodeDecodeError:
        with open(input_file, 'r', encoding='latin-1') as file:
            contenido_transformado = file.read()

    # Realizar las transformaciones con expresiones regulares
    # Eliminar saltos de línea si son más de dos
    contenido_transformado = re.sub(r'\n{2,}', '\n', contenido_transformado)
    # contenido_transformado = contenido_transformado.replace("\n", " ")

    # Limpiar mediante expresiones regulares
    # contenido_transformado = re.sub(r'[^A-Za-z0-9,.\- áÁéÉíÍóÓúÚñÑ]+', ' ', contenido_transformado)
    contenido_transformado = re.sub(r'[^A-Za-z0-9,.\- áÁéÉíÍóÓúÚñÑ?!;:()"\'\n]+', ' ', contenido_transformado)

    # Quitar guiones y puntos sin sentido
    # NO BORRAR PARA TRANSFORMERS
    # contenido_transformado = re.sub(r'\.{2,}-', ' ', contenido_transformado)

    # Quitar guiones consecutivos
    contenido_transformado = re.sub(r'-{2,}', ' ', contenido_transformado)

    # Quitar puntos consecutivos
    # SOLO QUITAR SI SON MAS DE 3 PUNTOS
    # contenido_transformado = re.sub(r'\.{2,}', '.', contenido_transformado)
    contenido_transformado = re.sub(r'\.{4,}', '...', contenido_transformado)

    # Más puntos consecutivos
    # NO BORRAR PARA TRANSFORMERS
    # contenido_transformado = re.sub(r'\.{1,} ', ' ', contenido_transformado)

    # Quitar todos los espacios de más
    contenido_transformado = re.sub(r'  +', ' ', contenido_transformado)

    # A partir de este punto, la variable 'contenido' contiene el texto limpio en Python

    # Aquí, reemplazaremos todas las instancias de "buscar" con "reemplazar"
    # ESTO POR QUÉ?
    # contenido_transformado = re.sub(r'buscar', 'reemplazar', contenido_transformado)

    # Crear el directorio de salida si no existe
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Combinar el directorio de salida y el nombre de archivo de salida
    ruta_salida = os.path.join(output_folder, output_filename)

    # Guardar el archivo transformado
    with open(ruta_salida, 'w', encoding='utf-8') as output_file:
        output_file.write(contenido_transformado)

    print(f'Archivo transformado guardado en {ruta_salida}')

# Directorio que contiene los archivos a procesar
# input_folder = r'/Users/joccerrillo/Downloads/convertidos'
input_folder = 'corpus/convertidos'

# Directorio donde se guardarán los archivos transformados
# output_folder = r'/Users/joccerrillo/Downloads/convertidos/Limpiados'
output_folder = 'corpus/convertidos/cleaned'

# Asegúrate de que el directorio de salida exista
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Lista de archivos en el directorio de entrada
files = os.listdir(input_folder)

# Itera sobre cada archivo en el directorio
for file in files:
    # Verifica que el elemento sea un archivo y no un directorio
    if os.path.isfile(os.path.join(input_folder, file)):
        # Genera un nombre de archivo de salida basado en el nombre del archivo de entrada
        output_filename = f"cleaned_{file}"
        
        # Llama a la función para transformar y guardar el archivo
        transformar_y_guardar_archivo(
            os.path.join(input_folder, file),
            output_folder,
            output_filename
        )
# Out:
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_55306_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_41039_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_79423_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84989_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_60808_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_37925_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_69588_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_30734_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_72683_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40156_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_93621_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_94166_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39247_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_98294_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40016_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_24385_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25719_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85216_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_99577_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_70387_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_60979_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40299_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26063_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_83547_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_37920_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86571_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_74743_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_41083_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_66339_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_56891_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_22519_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_38158_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_52708_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86441_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_60797_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84580_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_70839_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_78284_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_98720_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86200_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_80485_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_97671_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85034_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26313_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85633_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_59341_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_82665_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_30465_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_82660_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85131_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_24218_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25840_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_98263_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_66922_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40235_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_55563_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_24052_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25773_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_77227_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_23504_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_87625_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_47282_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_65632_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_82538_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_98008_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_81033_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_30456_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40458_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39107_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_80356_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_94551_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_69216_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_78844_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_82673_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39048_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39376_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_23439_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_97658_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25809_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_38087_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_94043_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_24219_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_93540_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_70400_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_41167_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_71120_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86281_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_55569_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86338_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84605_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_81117_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_90505_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_99307_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_72773_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_30460_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_53833_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_23312_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85089_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_79440_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_67993_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_38432_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_79956_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_37897_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26056_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_80345_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_87667_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_38827_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_99607_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26662_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_72715_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_47095_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_102158_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86260_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86293_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_52719_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_77216_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_62413_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_58470_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_87641_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_69361_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26100_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25799_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40548_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84521_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_38832_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_38811_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_88678_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_91850_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26295_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_80514_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_101756_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_81362_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_52724_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_91045_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_65633_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_52674_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86258_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_70388_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_61204_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26254_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_24288_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_82550_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39582_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39211_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_41070_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26347_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86657_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_78846_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_56890_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_71123_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26105_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_100317_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_38091_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_90832_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40545_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_97561_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_75367_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_90932_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_90799_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40716_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_70430_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_101816_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_81031_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_89787_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39695_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_23886_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_51864_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_66246_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_83567_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_38275_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_30452_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_72657_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_101857_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_31027_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_48054_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_50853_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86400_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_23930_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_98965_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_63136_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39118_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_82934_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_75357_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_68951_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_69487_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_31862_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_31278_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_69132_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_79554_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40936_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_97283_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_78661_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_101079_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40807_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_73430_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_102363_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85596_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40823_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_41118_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_90687_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40349_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_23535_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85635_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_80513_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_66256_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25723_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85203_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_87670_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_82556_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_97363_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40239_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_72653_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85226_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84103_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_62877_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_76324_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_95411_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39537_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_87504_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40666_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_38944_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_62862_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_24443_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_79917_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85118_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_92329_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_30131_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_49980_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_101448_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_96183_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86412_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_76306_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_23986_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_55105_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25759_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_41030_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_94370_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86994_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84603_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_29027_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40887_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_93282_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_60819_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26665_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_24383_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_96557_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_98290_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85202_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39386_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39100_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26290_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_89777_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_76335_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_22985_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25444_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_61217_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25739_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_95389_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_48487_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_102141_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26969_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_55292_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39092_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26076_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_78864_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_82931_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_47280_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_98722_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84947_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_89867_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86667_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_72746_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_22671_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_78866_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_38911_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_51068_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_41165_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86427_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_74970_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_75060_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40137_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84564_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_30225_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_31301_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85649_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_97831_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40017_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_78327_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_24386_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_59716_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40711_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_97950_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_62868_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_51530_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_82843_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_30933_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85637_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39861_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_97933_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_70432_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_51524_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_68740_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_77213_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_23965_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_54826_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86279_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_54552_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_72786_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_81083_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39731_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25765_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_55059_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_66227_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_93902_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_100385_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_23632_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26980_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_60796_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_88201_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_23838_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_79959_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_61879_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_65647_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_32855_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_53781_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_23916_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_31298_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_75912_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85099_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_101852_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84775_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_48471_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40173_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_51525_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_78865_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_74857_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39461_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_38150_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86647_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_59175_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84997_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_55573_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_28990_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_97288_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40631_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_90440_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_78019_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_41046_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_30751_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25947_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85018_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_98142_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39105_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_41068_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40404_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_47300_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_90390_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_78338_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85229_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_82855_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_74973_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_90391_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_79403_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_61226_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_68661_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_59202_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_30749_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84494_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_74856_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_23931_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26102_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26087_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84093_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84780_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_82856_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84631_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_98786_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_72008_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86370_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_70416_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40301_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_95824_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_97368_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_52182_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_23943_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_79938_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_24019_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_79439_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_49910_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_54765_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_51408_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_100194_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_93632_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_72865_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_70436_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_90822_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_60812_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_66228_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_80415_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_70380_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_98810_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86290_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_54175_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_24371_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_22969_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_54827_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40199_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_73385_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_53395_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40215_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_79416_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85192_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85161_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_79510_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85273_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85173_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_81345_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_51541_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40937_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84691_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84715_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40535_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_31351_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_90503_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_98533_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_96430_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_54555_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_101734_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_38135_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_90127_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40744_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_72690_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_81374_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25245_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_53390_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84599_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_72685_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_65279_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_72656_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_65248_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_102577_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_38274_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_89790_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_97740_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40269_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_98699_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_23638_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_23826_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_41054_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_74454_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84660_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_81361_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_38948_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_71625_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_52680_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25942_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_24702_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40791_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_47049_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26080_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_24292_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26128_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_91256_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_89881_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_79483_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_41062_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40401_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_78314_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_88105_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_61211_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_29001_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84484_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_70600_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_79469_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_67206_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_28996_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_23311_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_72325_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_66344_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_47173_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_49652_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_22958_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_50593_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_93275_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_66263_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_38148_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_75391_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_87004_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_62899_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_47171_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_97743_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_91251_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_98877_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40168_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_32856_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_93605_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_90694_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40541_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_90379_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_47490_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_80199_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_38982_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84634_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_23885_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_81373_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_78841_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_94363_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_87388_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_77186_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26062_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_23989_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_62417_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_52683_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_23516_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39351_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_95968_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85591_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86438_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_58387_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84543_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_24293_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_55734_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_55612_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25946_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_32275_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_78665_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_75072_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_94368_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_98706_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40203_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_70396_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_72006_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_96554_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_77222_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_90381_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_90220_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85067_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84600_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_65249_convertido.txt
# ...
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_67202_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85619_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_93970_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_79906_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_97622_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25941_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25767_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_66292_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_91525_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_70398_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_87159_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_72751_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85817_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40873_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_90933_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39521_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_98260_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_66291_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_90428_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39946_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_60336_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_24079_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_79436_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_49986_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86664_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_46711_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_75076_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_91060_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_51118_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_56472_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_37866_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_94542_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_88560_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_31856_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_54617_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_24739_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_100543_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_100560_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_38156_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_82663_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25831_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_83508_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39544_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84665_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_89829_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_31859_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_99579_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_75925_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_37863_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_58388_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_38163_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_99868_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_77223_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_79441_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_37936_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84769_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84776_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_77176_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_67854_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_72782_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85017_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_83557_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_54620_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25115_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_87072_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_97748_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39936_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_79545_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39564_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86256_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25760_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_91444_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_96552_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40888_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39169_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_66341_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26096_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_50850_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39903_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_54619_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_98140_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_79900_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_98069_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_87003_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_55060_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40972_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_100264_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_60807_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_24087_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39867_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_75975_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_47488_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_78679_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_55698_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_83552_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_57686_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_81086_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_74701_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_90797_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_30564_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_72319_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_70628_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_96006_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84664_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85023_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86282_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_30758_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_22516_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_97745_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_98147_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_101146_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85008_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_90441_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25725_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_55711_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_74967_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_81106_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_84786_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_69585_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_99542_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86252_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_66342_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_41172_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_76325_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39623_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_54621_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85611_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40794_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_97207_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25832_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_31338_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86299_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39091_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_41001_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25761_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_48173_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_47603_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40829_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_101083_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25820_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_51862_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_97390_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_68956_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_23629_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_80337_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26971_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_24107_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40445_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39841_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_87662_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_22970_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40247_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86261_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_53251_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_60785_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_87088_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_60821_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_91469_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26090_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_31296_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_46698_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_39776_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_76020_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85146_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_51539_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_72330_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_25777_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_22717_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_40002_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_85818_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_86384_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_26281_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_56918_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_91475_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_68838_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_70408_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_52720_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_32138_convertido.txt
# Archivo transformado guardado en corpus/convertidos/cleaned/cleaned_80348_convertido.txt

# %%
# count files in folder corpus/convertidos/cleaned
path, dirs, files = next(os.walk(output_folder))
file_count = len(files)
print(f'Cantidad de archivos transformados: {file_count}')
# Out:
# Cantidad de archivos transformados: 5000
